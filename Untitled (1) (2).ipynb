# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import re
import datetime
import scipy.stats as stats
import statistics

# %%
#Lectura
data = pd.read_csv('results.csv', sep=';')
#Columnas
data.columns = ['Fecha','IP Origen','IP Destino','Servicio','Accion','doc_count']
#Serie a Str
data['IP Destino'] = data['IP Destino'].map(str)
data['IP Origen'] = data['IP Origen'].map(str)
#De Epochs a Fecha
data['Fecha'] = data['Fecha'].astype(str).str[:-3]
data['Fecha'] = pd.to_datetime(data['Fecha'], unit = 's')
# Transformamos la columna Servicio a Puerto
def limpiar_servicio(servicio):
    string=re.search('\(([^)]+)', servicio).group(1)
    return string
data['Servicio']=data['Servicio'].apply(limpiar_servicio)

df1=data

# Creamos IP TYPE con el fin de diferenciar nuestra clasificación

# ip priv
# https://es.wikipedia.org/wiki/Red_privada
df1['IP Destino']=df1['IP Destino'].map(str)

df1.loc[(df1['IP Destino'].str.startswith('10.', na = False) == True)|
        (df1['IP Destino'].str.startswith('169.254', na = False) == True)|
        (df1['IP Destino'].str.startswith(('172.16','172.17','172.18','172.19','172.20','172.21','172.22', '172.23','172.24','172.25','172.26','172.27','172.28','172.29','172.30','172.31'), na = False) == True)|
        (df1['IP Destino'].str.startswith('192.168', na = False) == True), 'ip_type_destino'] = 'Int'
df1['ip_type_destino'] = df1['ip_type_destino'].fillna('Ext')


# Creamos Port Lvl con el fin de identificar los puertos comunmente atacados:

df1['Servicio']=df1['Servicio'].map(str)

df1.loc[
    # FTP 
        (df1['Servicio'] =='20')|
        (df1['Servicio'] =='21')|
    # SSH
        (df1['Servicio'] == '22')|
    # Telnet
         (df1['Servicio'] == '23')|
    # SMTP -> Por e-mail, spam
        (df1['Servicio'] == '25')|
    # DNS -> Ataques DDoS
         (df1['Servicio'] == '53')|
         (df1['Servicio'] == '88')|
         (df1['Servicio'] == '445')|
    #
         (df1['Servicio'] == '110')|
    #
         (df1['Servicio'] == '135')|
    #
         (df1['Servicio'] == '137')|
    #
         (df1['Servicio'] == '138')|
    # NetBIOS -> Impresora
         (df1['Servicio'] == '139')|
    # SQL Server y MySQL  puertos por default -> distribución de Malware
         (df1['Servicio'] == '1433')|
    #
         (df1['Servicio'] == '1434')|
    #
         (df1['Servicio'] == '3306')|
    # Postgres SQL
         (df1['Servicio'] == '5432')|
    # Escritorio remoto
         (df1['Servicio'] == '3389'), 'Port Lvl'] = 'Peligroso'

df1['Port Lvl'] = df1['Port Lvl'].fillna('Seguro')

# Para identificar el estatus 

df1['aux_indx'] = df1.index
df1['IP Origen']=df1['IP Origen'].map(str)
df1.loc[(df1['IP Origen'].str.startswith('10.', na = False) == True)|
        (df1['IP Origen'].str.startswith('169.254', na = False) == True)|
        (df1['IP Origen'].str.startswith(('172.16','172.17','172.18','172.19','172.20','172.21','172.22', '172.23','172.24','172.25','172.26','172.27','172.28','172.29','172.30','172.31'), na = False) == True)|
        (df1['IP Origen'].str.startswith('192.168', na = False) == True), 'ip_type_origen'] = 'Int'
df1['ip_type_origen'] = df1['ip_type_origen'].fillna('Ext')
df1.loc[(df1['ip_type_origen']=='Int') & 
        (df1['ip_type_destino']=='Int'), 'ip_type_interaccion']='II' # Mayor influencia
df1.loc[(df1['ip_type_origen']=='Int') & (df1['ip_type_destino']=='Ext'), 'ip_type_interaccion']='IE'
df1.loc[(df1['ip_type_origen']=='Ext') & (df1['ip_type_destino']=='Int'), 'ip_type_interaccion']='EI'
df1.loc[(df1['ip_type_origen']=='Ext') & (df1['ip_type_destino']=='Ext'), 'ip_type_interaccion']='EE'
df1['Accion']=df1['Accion'].map(str)
df1.loc[
    # No pasó el firewall
        (df1['Accion'] == 'drop')|
        (df1['Accion'] == 'stop')|
        (df1['Accion'] == 'reject'),
    'Action'] = 'No Paso'

df1['Action'] = df1['Action'].fillna('Paso')

data_ii1 = df1[df1['ip_type_interaccion']=='II']
data_ie1 = df1[df1['ip_type_interaccion']=='IE']
data_ei1 = df1[df1['ip_type_interaccion']=='EI']
data_int = pd.concat([data_ii1,data_ie1,data_ei1])
data_int = data_int.sort_values(by = 'aux_indx')

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoder = LabelEncoder()

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.covariance import EllipticEnvelope
from sklearn.ensemble import IsolationForest

def anomaly_labeler_IForest1(df):
    data = df[['Fecha','Action','IP Destino','Port Lvl', 'doc_count']]

    encoder_ip_destino = LabelEncoder.fit(data['IP Destino'])
    data['IP Destino'] = encoder_ip_destino.fit_transform(data['IP Destino'])
    
    encoder_action = LabelEncoder.fit(data['Action'])
    data['Action'] = encoder_action.fit_transform(data['Action'])

    encoder_port_lvl = LabelEncoder.fit(data['Port Lvl'])
    data['Port Lvl'] = LabelEncoder.fit_transform(data['Port Lvl'])

    encoder_date = LabelEncoder.fit(data['Fecha'])
    data['Fecha'] = LabelEncoder.fit_transform(data['Fecha'])
    
    outliers_fraction=0.1
    scaler = StandardScaler()
    data['doc_count'] = scaler.fit_transform(data['doc_count'].values.reshape(-1, 1))
    model =  IsolationForest(contamination=outliers_fraction, n_estimators=150)
    model.fit(data)
    df['anomaly_iForest1'] = model.predict(data)
    return df
    
def anomaly_labeler_IForest11(df):
    data = df[['Fecha','Action','IP Destino','Port Lvl','IP Origen', 'doc_count']]

    encoder_ip_destino = LabelEncoder.fit(data['IP Destino'])
    data['IP Destino'] = encoder_ip_destino.fit_transform(data['IP Destino'])

    encoder_ip_origen = LabelEncoder.fit(data['IP Origen'])
    data['IP Origen'] = encoder_ip_destino.fit_transform(data['IP Origen'])
    
    encoder_action = LabelEncoder.fit(data['Action'])
    data['Action'] = encoder_action.fit_transform(data['Action'])

    encoder_port_lvl = LabelEncoder.fit(data['Port Lvl'])
    data['Port Lvl'] = LabelEncoder.fit_transform(data['Port Lvl'])

    data['dia'] = data['Fecha'].apply(lambda x: x.day)
    data['weekday'] = data['Fecha'].apply(lambda x: x.weekday())
    data['hora'] = data['Fecha'].apply(lambda x: x.hour)
    data=data[['dia','weekday','hora','Action','IP Destino','Port Lvl','IP Origen', 'doc_count']]
    
    outliers_fraction=0.1
    scaler = StandardScaler()
    data['doc_count'] = scaler.fit_transform(data['doc_count'].values.reshape(-1, 1))
    model =  IsolationForest(contamination=outliers_fraction, n_estimators=150)
    model.fit(data)
    df['anomaly_iForest1'] = model.predict(data)
    return df

def get_origin_ip_list(data_original):
    print()
    
def transform_dataset(data_original):
    data_original = data_original.set_index('aux_indx')

# %%
data_int = pd.concat([data_ii1,data_ie1,data_ei1])
data_int = data_int.sort_values(by = 'Fecha')
data_int_day1 = data_int.set_index('Fecha').loc['2021-09-16 02:00':'2021-09-17 02:00']
data_int_day1 = data_int_day1.reset_index()

lista = data_int_day1['IP Origen'].value_counts().to_list()
lista2 = data_int_day1['IP Origen'].value_counts().index.to_list()
l2 = [x for x in lista if x>=186]
l3 = [x for x in lista if x< 186]

iplist = []
iplist2 = []
for i in range(0,len(l2)):
    iplist.append(lista2[i])
for i in range(len(l2),len(l2)+len(l3)):
    iplist2.append(lista2[i])

dic={}
for i in range(len(iplist)):
    dic[i] = anomaly_labeler_IForest1(data_int_day1[data_int_day1['IP Origen']==str(iplist[i])])
final = pd.concat(dic.values())

dic1={}
for i in range(len(iplist2)):
    dic1[i]=data_int_day1[data_int_day1['IP Origen']==str(iplist2[i])]
final11 = pd.concat(dic1.values())
final2 = anomaly_labeler_IForest11(final11)
final_dia1 = pd.concat([final,final2]).sort_values(by='aux_indx')
# Out:
# <ipython-input-3-02bc0edd0df0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['IP Destino'] = encoder_ip_destino.fit_transform(data['IP Destino'])
# <ipython-input-3-02bc0edd0df0>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Action'] = encoder_action.fit_transform(data['Action'])
# <ipython-input-3-02bc0edd0df0>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
    data = data_int_day1[['Fecha','Action','IP Destino','Port Lvl','IP Origen', 'doc_count']]
    
    encoder_ip_destino = LabelEncoder.fit(data['IP Destino'])
    data['IP Destino'] = encoder_ip_destino.fit_transform(data['IP Destino'])

    encoder_ip_origen = LabelEncoder.fit(data['IP Origen'])
    data['IP Origen'] = encoder_ip_destino.fit_transform(data['IP Origen'])
    
    encoder_action = LabelEncoder.fit(data['Action'])
    data['Action'] = encoder_action.fit_transform(data['Action'])
    
    encoder_port_lvl = LabelEncoder.fit(data['Port Lvl'])
    data['Port Lvl'] = LabelEncoder.fit_transform(data['Port Lvl'])

    data['dia'] = data['Fecha'].apply(lambda x: x.day)
    data['weekday'] = data['Fecha'].apply(lambda x: x.weekday())
    data['hora'] = data['Fecha'].apply(lambda x: x.hour)
    data=data[['dia','weekday','hora','Action','IP Destino','Port Lvl','IP Origen', 'doc_count']]
    
    outliers_fraction=0.08
    scaler = StandardScaler()
    data['doc_count'] = scaler.fit_transform(data['doc_count'].values.reshape(-1, 1))
    model =  IsolationForest(contamination=outliers_fraction, n_estimators=150)
    model.fit(data)
    data_int_day1['anomaly_iForest2'] = model.predict(data)
    data_int_day1 = data_int_day1.sort_values(by='aux_indx')
    final_dia1['anomaly_iForest2']=data_int_day1['anomaly_iForest2']
# Out:
# <ipython-input-5-a20ff538adf1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['IP Destino'] = encoder_ip_destino.fit_transform(data['IP Destino'])
# <ipython-input-5-a20ff538adf1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['IP Origen'] = encoder_ip_destino.fit_transform(data['IP Origen'])
# <ipython-input-5-a20ff538adf1>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from sklearn.neighbors import LocalOutlierFactor
from sklearn.decomposition import PCA
def anomaly_labeler_lof1(df):
    data = df[['Fecha','Action','IP Destino','Port Lvl', 'doc_count']]

    encoder_ip_destino = LabelEncoder.fit(data['IP Destino'])
    data['IP Destino'] = encoder_ip_destino.fit_transform(data['IP Destino'])
    
    encoder_action = LabelEncoder.fit(data['Action'])
    data['Action'] = encoder_action.fit_transform(data['Action'])

    encoder_port_lvl = LabelEncoder.fit(data['Port Lvl'])
    data['Port Lvl'] = LabelEncoder.fit_transform(data['Port Lvl'])

    data['dia'] = data['Fecha'].apply(lambda x: x.day)
    data['weekday'] = data['Fecha'].apply(lambda x: x.weekday())
    data['hora'] = data['Fecha'].apply(lambda x: x.hour)
    data=data[['dia','weekday','hora','Action','IP Destino','Port Lvl', 'doc_count']]
    outliers_fraction=0.1
    scaler = StandardScaler()
    data['doc_count'] = scaler.fit_transform(data['doc_count'].values.reshape(-1, 1))
    pca = PCA(n_components=2)
    pca.fit(data)
    X_pca = pca.transform(data)
    model =  LocalOutlierFactor(n_neighbors = 20, contamination=outliers_fraction)
    df['anomaly_LOF1'] = model.fit_predict(data)
    return df
def anomaly_labeler_lof11(df):
    data = df[['Fecha','Action','IP Destino','Port Lvl','IP Origen', 'doc_count']]

    encoder_ip_destino = LabelEncoder.fit(data['IP Destino'])
    data['IP Destino'] = encoder_ip_destino.fit_transform(data['IP Destino'])

    encoder_ip_origen = LabelEncoder.fit(data['IP Origen'])
    data['IP Origen'] = encoder_ip_destino.fit_transform(data['IP Origen'])
    
    encoder_action = LabelEncoder.fit(data['Action'])
    data['Action'] = encoder_action.fit_transform(data['Action'])

    encoder_port_lvl = LabelEncoder.fit(data['Port Lvl'])
    data['Port Lvl'] = LabelEncoder.fit_transform(data['Port Lvl'])

    data['dia'] = data['Fecha'].apply(lambda x: x.day)
    data['weekday'] = data['Fecha'].apply(lambda x: x.weekday())
    data['hora'] = data['Fecha'].apply(lambda x: x.hour)
    data=data[['dia','weekday','hora','Action','IP Destino','Port Lvl','IP Origen', 'doc_count']]
    outliers_fraction=0.1
    scaler = StandardScaler()
    data['doc_count'] = scaler.fit_transform(data['doc_count'].map(float).values.reshape(-1, 1))
    pca = PCA(n_components=2)
    pca.fit(data)
    X_pca = pca.transform(data)
    model =  LocalOutlierFactor(n_neighbors = 20, contamination=outliers_fraction)
    df['anomaly_LOF1'] = model.fit_predict(data)
    return df

# %%
dic2={}
for i in range(len(iplist)):
    dic2[i] = anomaly_labeler_lof1(data_int_day1[data_int_day1['IP Origen']==str(iplist[i])])
final_lof = pd.concat(dic2.values())

dic3={}
for i in range(len(iplist2)):
    dic3[i]=data_int_day1[data_int_day1['IP Origen']==iplist2[i]]
final11_lof = pd.concat(dic3.values())
final_lof2 = anomaly_labeler_lof11(final11_lof)
final_dia1_LOF = pd.concat([final_lof,final_lof2]).sort_values(by='aux_indx')  

final_dia1['anomaly_LOF1'] = final_dia1_LOF['anomaly_LOF1']
# Out:
# <ipython-input-6-2b9f80232d89>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['IP Destino'] = encoder_ip_destino.fit_transform(data['IP Destino'])
# <ipython-input-6-2b9f80232d89>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Action'] = encoder_action.fit_transform(data['Action'])
# <ipython-input-6-2b9f80232d89>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data_int['IP Origen'].value_counts().quantile(0.5)
# Out:
# 117.0

# %%
# IP Profile: 

# - En que horario la IP tiene mayor actividad? Cambio de actividad en el horario -> Cambio en Pesos!
# - Determinar si normalmente pasa o no pasa, si pasa -> Cambio en los pesos
# - Puertos a los que mas se conecta! Modificar pesos según los puertos a los que mas se conecta. 

def ip_profiling(data):
    
    lista = data['IP Origen'].value_counts().to_list()
    
    lista2 = data['IP Origen'].value_counts().index.to_list()
    
    quant_connections = data['IP Origen'].value_counts().quantile(0.6)
    
    l2 = [x for x in lista if x>=quant_connections]
    l3 = [x for x in lista if x< quant_connections]

    iplist = []
    iplist2 = []
    
    for i in range(0,len(l2)):
        
        iplist.append(lista2[i])
        
    for i in range(len(l2),len(l2)+len(l3)):
        
        iplist2.append(lista2[i])

    dict_ips = {}
    
    for i in range(len(iplist)):
        # empezamos a perfilar las ip's
        df_to_work = data[data['IP Origen']==iplist[i]]
        df_to_work_day = data[data['IP Origen']==iplist[i]].set_index('Fecha').between_time('07:00','19:00')
        df_to_work_night = data[data['IP Origen']==iplist[i]].set_index('Fecha').between_time('20:00','06:00')
        df_to_work = df_to_work.reset_index()
        df_to_work_day = df_to_work_day.reset_index()
        df_to_work_night = df_to_work_night.reset_index()
        df_to_work['Profile']=0
        df_to_work_day['Profile']=0
        df_to_work_night['Profile']=0
        
        value11 = (len(df_to_work_day)/len(df_to_work) > len(df_to_work_night)/len(df_to_work))
        value12 = (len(df_to_work_night)/len(df_to_work) > len(df_to_work_day)/len(df_to_work))
        value21 = (len(df_to_work[df_to_work['Action']=='No Paso'])/len(df_to_work) > len(df_to_work[df_to_work['Action']=='Paso'])/len(df_to_work))
        value22 = (len(df_to_work[df_to_work['Action']=='Paso'])/len(df_to_work) > len(df_to_work[df_to_work['Action']=='No Paso'])/len(df_to_work)) 
        value31 = (len(df_to_work[df_to_work['Port Lvl']=='Seguro'])/len(df_to_work) > len(df_to_work[df_to_work['Port Lvl']=='Peligroso'])/len(df_to_work))
        value32 = (len(df_to_work[df_to_work['Port Lvl']=='Peligroso'])/len(df_to_work) > len(df_to_work[df_to_work['Port Lvl']=='Seguro'])/len(df_to_work))
        
        
        # CASO 1
        
        if value11 & value21 & value31:
            # Si es de día -> Comportamiento anormal se penaliza, comportamientos extremos se penalizan.
            
            # local
            
            df_to_work_day.loc[df_to_work_day['Action']=='Paso', 'Profile'] += 1
            
            df_to_work_day.loc[df_to_work_day['Port Lvl']=='Peligroso','Profile'] += 1.5
            
            df_to_work_day.loc[(df_to_work_day['Action']=='Paso')&(df_to_work_day['Port Lvl']=='Peligroso')&(df_to_work_day['doc_count']>=df_to_work_day['doc_count'].quantile(0.9)),'Profile']+=1
            
            
            
            # global
            
            df_to_work_day.loc[df_to_work_day['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

            df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count']) & (df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Si es de noche (de por sí es anormal en esta IP)
            
            
            # local
            
            df_to_work_night.loc[df_to_work_night['Action']=='Paso', 'Profile'] += 1.5
            
            df_to_work_night.loc[df_to_work_night['Port Lvl']=='Peligroso','Profile'] += 1.5
            
            df_to_work_night.loc[df_to_work_night['doc_count']>= df_to_work_night['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
            
            df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
            df_to_work_night.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count']) & (df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
    
                
        
        # CASO 2
        
        elif value11 & value21 & value32 :
          
            
            # Si es de día -> Comportamiento anormal se penaliza, comportamientos extremos se penalizan.
            
            
            # local
            
            df_to_work_day.loc[df_to_work_day['Action']=='Paso', 'Profile'] += 1
            
            df_to_work_day.loc[(df_to_work_day['Action']=='Paso')&(df_to_work_day['Port Lvl']=='Peligroso')&(df_to_work_day['doc_count']>=df_to_work_day['doc_count'].quantile(0.9)),'Profile']+=1
            
            
            
            # global
            
            df_to_work_day.loc[df_to_work_day['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

            df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count']) & (df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Si es de noche (de por sí es anormal en esta IP)
            
            
            # local
            
            df_to_work_night.loc[df_to_work_night['Action']=='Paso', 'Profile'] += 1.5
            
            df_to_work_night.loc[df_to_work_night['Port Lvl']=='Peligroso','Profile'] += 1.5
            
            df_to_work_night.loc[df_to_work_night['doc_count']>= df_to_work_night['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
            df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
            df_to_work_night.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count']) & (df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
    
        
        #CASO 3
        
        elif value11 & value22 & value31 :
            
            # Si es de día -> Comportamiento anormal se penaliza, comportamientos extremos se penalizan.
            
            # local
            
            df_to_work_day.loc[df_to_work_day['Port Lvl']=='Peligroso','Profile'] += 1.5
            
            df_to_work_day.loc[(df_to_work_day['Action']=='Paso')&(df_to_work_day['Port Lvl']=='Peligroso')&(df_to_work_day['doc_count']>=df_to_work_day['doc_count'].quantile(0.9)),'Profile'] += 1.5
            
            
            
            # global
            
            df_to_work_day.loc[df_to_work_day['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

            df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count']) & (df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Si es de noche (de por sí es anormal en esta IP)
            
            
            # local
            

            
            df_to_work_night.loc[df_to_work_night['Port Lvl']=='Peligroso','Profile'] += 1.5
            
            df_to_work_night.loc[df_to_work_night['doc_count']>= df_to_work_night['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
            
            df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
            df_to_work_night.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count']) & (df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
    
        
        # CASO 4
        elif value11 & value22 & value32 :
            
            # Si es de día -> Comportamiento anormal se penaliza, comportamientos extremos se penalizan.
            
            # local
            
            
            df_to_work_day.loc[(df_to_work_day['Action']=='Paso')&(df_to_work_day['Port Lvl']=='Peligroso')&(df_to_work_day['doc_count']>=df_to_work_day['doc_count'].quantile(0.9)),'Profile']+=1
            
            
            
            # global
            
            df_to_work_day.loc[df_to_work_day['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

            df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count']) & (df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Si es de noche (de por sí es anormal en esta IP)
            
            
            # local
            
            
            df_to_work_night.loc[df_to_work_night['doc_count']>= df_to_work_night['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
            
            df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
            df_to_work_night.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count']) & (df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
    
        
        # CASO 5
        
        elif value12 & value21 & value31 :
            
            # Si es de noche -> Comportamiento anormal se penaliza, comportamientos extremos se penalizan.
                       
            
            # local
            
            df_to_work_night.loc[df_to_work_night['Action']=='Paso', 'Profile'] += 1
            
            df_to_work_night.loc[df_to_work_night['Port Lvl']=='Peligroso','Profile'] += 1.5
            
            df_to_work_night.loc[(df_to_work_night['Action']=='Paso')&(df_to_work_night['Port Lvl']=='Peligroso')&(df_to_work_night['doc_count']>=df_to_work_night['doc_count'].quantile(0.9)),'Profile']+=1
            
            
            
            # global
            
            df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

            df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count'])&(df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Si es de día (de por sí es anormal en esta IP)
            
            
            # local
            
            df_to_work_day.loc[df_to_work_day['Action']=='Paso', 'Profile'] += 1.5
            
            df_to_work_day.loc[df_to_work_day['Port Lvl']=='Peligroso','Profile'] += 1.5
            
            df_to_work_day.loc[df_to_work_day['doc_count']>= df_to_work_day['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
            
            df_to_work_day.loc[df_to_work_day['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
            df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count']) & (df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
        
        # CASO 6
        
        elif value12 & value21 & value32 :  
             
            # Noche
            
            # local
            
            df_to_work_night.loc[df_to_work_night['Action']=='Paso', 'Profile'] += 1
            
            df_to_work_night.loc[(df_to_work_night['Action']=='Paso')&(df_to_work_night['Port Lvl']=='Peligroso')&(df_to_work_night['doc_count']>=df_to_work_night['doc_count'].quantile(0.9)),'Profile']+=1
            
            
            
            # global
            
            df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

            df_to_work_night.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count'])&(df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Si es de día (de por sí es anormal en esta IP)
            
            
            # local
            
            df_to_work_day.loc[df_to_work_day['Action']=='Paso', 'Profile'] += 1.5
            
            df_to_work_day.loc[df_to_work_day['Port Lvl']=='Peligroso','Profile'] += 1.5
            
            df_to_work_day.loc[df_to_work_day['doc_count']>= df_to_work_day['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
            df_to_work_day.loc[df_to_work['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
            df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count'])&(df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
    
        # CASO 7
        
        elif value12 & value22 & value31:  
            
            # Noche
                
            # local
            
            df_to_work_night.loc[df_to_work_night['Port Lvl']=='Peligroso','Profile'] += 1.5
            
            df_to_work_night.loc[(df_to_work_night['Action']=='Paso')&(df_to_work_night['Port Lvl']=='Peligroso')&(df_to_work_night['doc_count']>=df_to_work_night['doc_count'].quantile(0.9)),'Profile'] += 1.5
            
            
            
            # global
            
            df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

            df_to_work_night.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count'])&(df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Si es de día (de por sí es anormal en esta IP)
            
            
            # local
            

            
            df_to_work_day.loc[df_to_work_day['Port Lvl']=='Peligroso','Profile'] += 1.5
            
            df_to_work_day.loc[df_to_work_day['doc_count']>= df_to_work_day['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
            
            df_to_work_day.loc[df_to_work_day['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
            df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count'])&(df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
    
        
        # CASO 8
        
        elif value12 & value22 & value32 :
            
            # Noche
            
            # local
            
            
            df_to_work_night.loc[(df_to_work_night['Action']=='Paso')&(df_to_work_night['Port Lvl']=='Peligroso')&(df_to_work_night['doc_count']>=df_to_work_night['doc_count'].quantile(0.9)),'Profile']+=1
            
            
            
            # global
            
            df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

            df_to_work_night.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count'])&(df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Día (de por sí es anormal en esta IP)
            
            
            # local
            
            
            df_to_work_day.loc[df_to_work_day['doc_count']>= df_to_work_day['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
            
            df_to_work_day.loc[df_to_work_day['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
            df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count'])&(df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
        # Ahora etiquetamos las anomalías
        
        df_to_dict = pd.concat([df_to_work_day,df_to_work_night]).sort_values(by='aux_indx')
        
        dict_ips[i] = df_to_dict
    
    df_to_work1 = pd.concat(dict_ips.values())
    
    
    dict_ips2 = {}
    
    
    for i in range(len(iplist2)):
        
        dict_ips2[i] = data[data['IP Origen']==iplist2[i]]
                   
    df_to_work2 = pd.concat(dict_ips2.values())
                   
    data = df_to_work2
                   
    df_to_work = data    
    df_to_work_day = data.set_index('Fecha').between_time('07:00','19:00')
    df_to_work_night = data.set_index('Fecha').between_time('20:00','06:00')
    df_to_work = df_to_work.reset_index()
    df_to_work_day = df_to_work_day.reset_index()
    df_to_work_night = df_to_work_night.reset_index()
    df_to_work['Profile']=0
    df_to_work_day['Profile']=0
    df_to_work_night['Profile']=0
                   
    value11 = (len(df_to_work_day)/len(df_to_work) > len(df_to_work_night)/len(df_to_work))
    value12 = (len(df_to_work_night)/len(df_to_work) > len(df_to_work_day)/len(df_to_work))
    value21 = (len(df_to_work[df_to_work['Action']=='No Paso'])/len(df_to_work) > len(df_to_work[df_to_work['Action']=='Paso'])/len(df_to_work))
    value22 = (len(df_to_work[df_to_work['Action']=='Paso'])/len(df_to_work) > len(df_to_work[df_to_work['Action']=='No Paso'])/len(df_to_work)) 
    value31 = (len(df_to_work[df_to_work['Port Lvl']=='Seguro'])/len(df_to_work) > len(df_to_work[df_to_work['Port Lvl']=='Peligroso'])/len(df_to_work))
    value32 = (len(df_to_work[df_to_work['Port Lvl']=='Peligroso'])/len(df_to_work) > len(df_to_work[df_to_work['Port Lvl']=='Seguro'])/len(df_to_work))
        
                   
    
    
        # CASO 1
        
    if value11 & value21 & value31 :
            
            # Si es de día -> Comportamiento anormal se penaliza, comportamientos extremos se penalizan.
            
            # local
            
        df_to_work_day.loc[df_to_work_day['Action']=='Paso', 'Profile'] += 1
            
        df_to_work_day.loc[df_to_work_day['Port Lvl']=='Peligroso','Profile'] += 1.5
            
        df_to_work_day.loc[(df_to_work_day['Action']=='Paso')&(df_to_work_day['Port Lvl']=='Peligroso')&(df_to_work_day['doc_count']>=df_to_work_day['doc_count'].quantile(0.9)),'Profile']+=1
            
            
            
            # global
            
        df_to_work_day.loc[df_to_work_day['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

        df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count']) & (df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Si es de noche (de por sí es anormal en esta IP)
            
            
            # local
            
        df_to_work_night.loc[df_to_work_night['Action']=='Paso', 'Profile'] += 1.5
            
        df_to_work_night.loc[df_to_work_night['Port Lvl']=='Peligroso','Profile'] += 1.5
            
        df_to_work_night.loc[df_to_work_night['doc_count']>= df_to_work_night['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
            
        df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
        df_to_work_night.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count']) & (df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
    
                
        
        # CASO 2
        
    elif value11 & value21 & value32 :
          
            
            # Si es de día -> Comportamiento anormal se penaliza, comportamientos extremos se penalizan.
            
            
            # local
            
        df_to_work_day.loc[df_to_work_day['Action']=='Paso', 'Profile'] += 1
            
        df_to_work_day.loc[(df_to_work_day['Action']=='Paso')&(df_to_work_day['Port Lvl']=='Peligroso')&(df_to_work_day['doc_count']>=df_to_work_day['doc_count'].quantile(0.9)),'Profile']+=1
            
            
            
            # global
            
        df_to_work_day.loc[df_to_work_day['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

        df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count']) & (df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Si es de noche (de por sí es anormal en esta IP)
            
            
            # local
            
        df_to_work_night.loc[df_to_work_night['Action']=='Paso', 'Profile'] += 1.5
            
        df_to_work_night.loc[df_to_work_night['Port Lvl']=='Peligroso','Profile'] += 1.5
            
        df_to_work_night.loc[df_to_work_night['doc_count']>= df_to_work_night['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
        df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
        df_to_work_night.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count']) & (df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
    
        
        #CASO 3
        
    elif value11 & value22 & value31 :
            
            # Si es de día -> Comportamiento anormal se penaliza, comportamientos extremos se penalizan.
            
            # local
            
        df_to_work_day.loc[df_to_work_day['Port Lvl']=='Peligroso','Profile'] += 1.5
            
        df_to_work_day.loc[(df_to_work_day['Action']=='Paso')&(df_to_work_day['Port Lvl']=='Peligroso')&(df_to_work_day['doc_count']>=df_to_work_day['doc_count'].quantile(0.9)),'Profile'] += 1.5
            
            
            
            # global
            
        df_to_work_day.loc[df_to_work_day['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

        df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count']) & (df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Si es de noche (de por sí es anormal en esta IP)
            
            
            # local
            

            
        df_to_work_night.loc[df_to_work_night['Port Lvl']=='Peligroso','Profile'] += 1.5
            
        df_to_work_night.loc[df_to_work_night['doc_count']>= df_to_work_night['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
            
        df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
        df_to_work_night.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count']) & (df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
    
        
        # CASO 4
    elif value11 & value22 & value32 :
            
            # Si es de día -> Comportamiento anormal se penaliza, comportamientos extremos se penalizan.
            
            # local
            
            
        df_to_work_day.loc[(df_to_work_day['Action']=='Paso')&(df_to_work_day['Port Lvl']=='Peligroso')&(df_to_work_day['doc_count']>=df_to_work_day['doc_count'].quantile(0.9)),'Profile']+=1
            
            
            
            # global
            
        df_to_work_day.loc[df_to_work_day['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

        df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count']) & (df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Si es de noche (de por sí es anormal en esta IP)
            
            
            # local
            
            
        df_to_work_night.loc[df_to_work_night['doc_count']>= df_to_work_night['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
            
        df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
        df_to_work_night.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count']) & (df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
    
        
        # CASO 5
        
    elif value12 & value21 & value31 :
            
            # Si es de noche -> Comportamiento anormal se penaliza, comportamientos extremos se penalizan.
                       
            
            # local
            
        df_to_work_night.loc[df_to_work_night['Action']=='Paso', 'Profile'] += 1
            
        df_to_work_night.loc[df_to_work_night['Port Lvl']=='Peligroso','Profile'] += 1.5
            
        df_to_work_night.loc[(df_to_work_night['Action']=='Paso')&(df_to_work_night['Port Lvl']=='Peligroso')&(df_to_work_night['doc_count']>=df_to_work_night['doc_count'].quantile(0.9)),'Profile']+=1
            
            
            
            # global
            
        df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

        df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count'])&(df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Si es de día (de por sí es anormal en esta IP)
            
            
            # local
            
        df_to_work_day.loc[df_to_work_day['Action']=='Paso', 'Profile'] += 1.5
            
        df_to_work_day.loc[df_to_work_day['Port Lvl']=='Peligroso','Profile'] += 1.5
            
        df_to_work_day.loc[df_to_work_day['doc_count']>= df_to_work_day['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
            
        df_to_work_day.loc[df_to_work_day['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
        df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count']) & (df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
        
        # CASO 6
        
    elif value12 & value21 & value32 :  
             
            # Noche
            
            # local
            
        df_to_work_night.loc[df_to_work_night['Action']=='Paso', 'Profile'] += 1
            
        df_to_work_night.loc[(df_to_work_night['Action']=='Paso')&(df_to_work_night['Port Lvl']=='Peligroso')&(df_to_work_night['doc_count']>=df_to_work_night['doc_count'].quantile(0.9)),'Profile']+=1
            
            
            
            # global
            
        df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

        df_to_work_night.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count'])&(df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Si es de día (de por sí es anormal en esta IP)
            
            
            # local
            
        df_to_work_day.loc[df_to_work_day['Action']=='Paso', 'Profile'] += 1.5
            
        df_to_work_day.loc[df_to_work_day['Port Lvl']=='Peligroso','Profile'] += 1.5
            
        df_to_work_day.loc[df_to_work_day['doc_count']>= df_to_work_day['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
        df_to_work_day.loc[df_to_work['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
        df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count'])&(df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
    
        # CASO 7
        
    elif value12 & value22 & value31 :  
            
            # Noche
                
            # local
            
        df_to_work_night.loc[df_to_work_night['Port Lvl']=='Peligroso','Profile'] += 1.5
            
        df_to_work_night.loc[(df_to_work_night['Action']=='Paso')&(df_to_work_night['Port Lvl']=='Peligroso')&(df_to_work_night['doc_count']>=df_to_work_night['doc_count'].quantile(0.9)),'Profile'] += 1.5
            
            
            
            # global
            
        df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

        df_to_work_night.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count'])&(df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Si es de día (de por sí es anormal en esta IP)
            
            
            # local
            

            
        df_to_work_day.loc[df_to_work_day['Port Lvl']=='Peligroso','Profile'] += 1.5
            
        df_to_work_day.loc[df_to_work_day['doc_count']>= df_to_work_day['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
            
        df_to_work_day.loc[df_to_work_day['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
        df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count'])&(df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
    
        
        # CASO 8
        
    elif value12 & value22 & value32 :
            
            # Noche
            
            # local
            
        
        df_to_work_night.loc[(df_to_work_night['Action']=='Paso')&(df_to_work_night['Port Lvl']=='Peligroso')&(df_to_work_night['doc_count']>=df_to_work_night['doc_count'].quantile(0.9)),'Profile']+=1
            
            
            
            # global
            
        df_to_work_night.loc[df_to_work_night['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2

        df_to_work_night.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_night['doc_count'])&(df_to_work_night['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
            
            
            # Día (de por sí es anormal en esta IP)
            
            
            # local
            
            
        df_to_work_day.loc[df_to_work_day['doc_count']>= df_to_work_day['doc_count'].quantile(0.98),'Profile'] += 2.5
            
            
            # global
            
            
        df_to_work_day.loc[df_to_work_day['doc_count']>df_to_work['doc_count'].quantile(0.99),'Profile'] += 2
            
        df_to_work_day.loc[(df_to_work['doc_count'].quantile(0.9)<df_to_work_day['doc_count'])&(df_to_work_day['doc_count']<df_to_work['doc_count'].quantile(0.98)),'Profile']+=1
            
       
        
    df_to_work3 = pd.concat([df_to_work_day, df_to_work_night])
                   
    return pd.concat([df_to_work1, df_to_work3]).sort_values(by = 'aux_indx')

# %%
# %%time

prueba = ip_profiling(data_int)
# Out:
# Wall time: 18min 11s

# %%
prueba.to_csv('prueba_nuevo.csv')

# %%
max(prueba[prueba['Profile']==0]['doc_count'])
# Out:
# 18544

# %%
prueba.loc[(prueba['doc_count']>=1000) & (prueba['Profile']==0) & (prueba['Port Lvl']=='Peligroso')].tail(60)
# Out:
#                    Fecha    IP Origen      IP Destino Servicio  Accion  \
# 131  2021-09-21 18:00:00   10.1.0.141         8.8.4.4       53    drop
# 131  2021-09-21 18:00:00     10.2.0.9         8.8.4.4       53    drop
# 131  2021-09-21 18:00:00   10.2.0.141         8.8.4.4       53    drop
# 130  2021-09-21 18:00:00   10.1.0.141         8.8.8.8       53    drop
# 130  2021-09-21 18:00:00     10.2.0.9         8.8.8.8       53    drop
# 130  2021-09-21 18:00:00   10.2.0.141         8.8.8.8       53    drop
# 130  2021-09-21 18:00:00   10.5.0.103         8.8.8.8       53    drop
# 132  2021-09-21 19:00:00  10.12.0.101         1.1.1.1       53    drop
# 132  2021-09-21 19:00:00   10.1.0.141         8.8.4.4       53    drop
# 132  2021-09-21 19:00:00     10.2.0.9         8.8.4.4       53    drop
# 132  2021-09-21 19:00:00   10.2.0.141         8.8.4.4       53    drop
# 133  2021-09-21 19:00:00   10.1.0.141         8.8.8.8       53    drop
# ...

# %%
prueba[(prueba['IP Origen']=='10.20.1.30') & (prueba['IP Destino']=='8.8.4.4')].head(60)
# Out:
#                    Fecha   IP Origen IP Destino Servicio  Accion  doc_count  \
# 7    2021-09-16 02:00:00  10.20.1.30    8.8.4.4       53  accept         49
# 27   2021-09-16 03:00:00  10.20.1.30    8.8.4.4       53  accept         22
# 39   2021-09-16 04:00:00  10.20.1.30    8.8.4.4       53  accept       2007
# 114  2021-09-16 05:00:00  10.20.1.30    8.8.4.4       53  accept       5771
# 362  2021-09-16 06:00:00  10.20.1.30    8.8.4.4       53    drop          6
# 361  2021-09-16 06:00:00  10.20.1.30    8.8.4.4       53  accept       4725
# 107  2021-09-16 07:00:00  10.20.1.30    8.8.4.4       53  accept       5318
# 255  2021-09-16 08:00:00  10.20.1.30    8.8.4.4       53  accept       6972
# 400  2021-09-16 09:00:00  10.20.1.30    8.8.4.4       53  accept       7345
# 510  2021-09-16 10:00:00  10.20.1.30    8.8.4.4       53  accept       7224
# 697  2021-09-16 11:00:00  10.20.1.30    8.8.4.4       53  accept       4878
# ...

# %%
q = statistics.quantiles(prueba[(prueba['IP Origen']=='10.20.1.30') & (prueba['IP Destino']=='8.8.4.4')]['Profile'])
anomaly1 = prueba.loc[(prueba['IP Origen']=='10.20.1.30') & (prueba['IP Destino']=='8.8.4.4')& (prueba['Profile']>q[2])]

# %%
anomaly1
# Out:
#                    Fecha   IP Origen IP Destino Servicio  Accion  doc_count  \
# 1072 2021-09-17 20:00:00  10.20.1.30    8.8.4.4       53  accept       7826
# 1240 2021-09-17 21:00:00  10.20.1.30    8.8.4.4       53  accept       8118
# 1273 2021-09-17 22:00:00  10.20.1.30    8.8.4.4       53  accept       8555
# 1443 2021-09-17 23:00:00  10.20.1.30    8.8.4.4       53  accept       8510
# 1783 2021-09-18 03:00:00  10.20.1.30    8.8.4.4       53  accept       8028
# 1944 2021-09-18 04:00:00  10.20.1.30    8.8.4.4       53  accept       8678
# 2144 2021-09-18 05:00:00  10.20.1.30    8.8.4.4       53  accept       7917
# 2297 2021-09-18 06:00:00  10.20.1.30    8.8.4.4       53  accept       8867
# 2991 2021-09-20 00:00:00  10.20.1.30    8.8.4.4       53  accept       8726
# 3248 2021-09-20 01:00:00  10.20.1.30    8.8.4.4       53  accept       8769
# 3270 2021-09-20 02:00:00  10.20.1.30    8.8.4.4       53  accept       8612
# ...

# %%
max(prueba[(prueba['IP Origen']=='10.20.1.30') & (prueba['IP Destino']=='8.8.4.4')]['doc_count'])
# Out:
# 61660

# %%
import plotly.graph_objects as go
import plotly.express as px

df = prueba[(prueba['IP Origen']=='10.20.1.30') & (prueba['IP Destino']=='8.8.4.4')]
fig = px.line(df, x='Fecha', y="doc_count")
fig.add_trace(go.Scatter(mode="markers", x=anomaly1["Fecha"], y=anomaly1["doc_count"], name="anom"))

fig.show()
# Out:
# <div>                            <div id="60261fe3-3b62-464d-9a17-fc7bc9a82dfb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60261fe3-3b62-464d-9a17-fc7bc9a82dfb")) {                    Plotly.newPlot(                        "60261fe3-3b62-464d-9a17-fc7bc9a82dfb",                        [{"hovertemplate":"Fecha=%{x}<br>doc_count=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-09-16T02:00:00","2021-09-16T03:00:00","2021-09-16T04:00:00","2021-09-16T05:00:00","2021-09-16T06:00:00","2021-09-16T06:00:00","2021-09-16T07:00:00","2021-09-16T08:00:00","2021-09-16T09:00:00","2021-09-16T10:00:00","2021-09-16T11:00:00","2021-0
# ...

# %%
df_to_work = data_int[data_int['IP Origen']=='10.13.216.178']
df_to_work_day = data_int[data_int['IP Origen']=='10.13.216.178'].set_index('Fecha').between_time('07:00','19:00')
df_to_work_night = data_int[data_int['IP Origen']=='10.13.216.178'].set_index('Fecha').between_time('08:00','06:00')
        # Aquí Día notoriamente mas activo que la noche:
df_to_work['Profile']=0
df_to_work_day['Profile']=0
df_to_work_night['Profile']=0
# Out:
# <ipython-input-12-4941c1f6ca3f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_to_work['Profile']=0

# %%
df_to_work_night.shape
# Out:
# (8627, 12)

# %%
stdev_day = statistics.stdev(df_to_work_day['doc_count'])
mean_day = statistics.mean(df_to_work_day['doc_count'])
df_to_work_day.loc[df_to_work_day['Action']=='Paso', 'Profile'] += 1
df_to_work_day.loc[df_to_work_day['Port Lvl']=='Peligroso','Profile'] += 1
df_to_work_day.loc[df_to_work_day['doc_count']>(stdev_day+mean_day),'Profile'] += 2

max(df_to_work[df_to_work['Port Lvl']=='Peligroso']['doc_count'])
# Out:
# 3

# %%
prueba1 = prueba

# %%
prueba1 = prueba1.set_index('Fecha').loc['2021-09-16 02:00':'2021-09-17 02:00']
prueba1 = prueba1.reset_index()

# %%
prueba1['anomaly_iForest1'] = final_dia1['anomaly_iForest1']

# %%
prueba1['Action'].value_counts()
# Out:
# Paso       292667
# No Paso     23419
# Name: Action, dtype: int64

# %%
prueba1[(prueba1['IP Origen']=='10.100.5.188') & (prueba1['IP Destino']=='10.20.1.219')].head(60)
# Out:
#                     Fecha     IP Origen   IP Destino Servicio  Accion  \
# 597   2021-09-16 02:00:00  10.100.5.188  10.20.1.219    28083  accept
# 598   2021-09-16 02:00:00  10.100.5.188  10.20.1.219    28181  accept
# 599   2021-09-16 02:00:00  10.100.5.188  10.20.1.219    28183  accept
# 600   2021-09-16 02:00:00  10.100.5.188  10.20.1.219    28184  accept
# 601   2021-09-16 02:00:00  10.100.5.188  10.20.1.219    28186  accept
# 602   2021-09-16 02:00:00  10.100.5.188  10.20.1.219    38080  accept
# 1767  2021-09-16 03:00:00  10.100.5.188  10.20.1.219    28083  accept
# 1768  2021-09-16 03:00:00  10.100.5.188  10.20.1.219    28181  accept
# 1769  2021-09-16 03:00:00  10.100.5.188  10.20.1.219    28183  accept
# 1770  2021-09-16 03:00:00  10.100.5.188  10.20.1.219    28184  accept
# 1771  2021-09-16 03:00:00  10.100.5.188  10.20.1.219    28186  accept
# 1772  2021-09-16 03:00:00  10.100.5.188  10.20.1.219    38080  accept
# ...

# %%
prueba1[prueba1['Action']=='No Paso']['Profile'].value_counts()
# Out:
# 0.0    20778
# 1.5     1447
# 1.0     1002
# 2.5      166
# 3.5       14
# 2.0       10
# 6.0        1
# 4.5        1
# Name: Profile, dtype: int64

# %%
final_dia1['anomaly_iForest1'].value_counts()
# Out:
#  1    284447
# -1     31639
# Name: anomaly_iForest1, dtype: int64

# %% [markdown]
# # Nuevo Approach

# %%
time_series_df = prueba[(prueba['IP Origen']=='10.20.1.30') & (prueba['IP Destino']=='8.8.4.4')]
actual_vals = time_series_df.doc_count.values
actual_log = np.log10(actual_vals)

# %%
import math
import statsmodels.api as sm
import statsmodels.tsa.api as smt
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot
import matplotlib.pyplot as plt

train, test = actual_vals[0:-70], actual_vals[-70:]
train_log, test_log = np.log10(train), np.log10(test)
my_order = (1, 1, 1)
my_seasonal_order = (0, 1, 1, 7)

# %%
history = [x for x in train_log]
predictions = list()
predict_log=list()
for t in range(len(test_log)):
    model = sm.tsa.SARIMAX(history, order=my_order, seasonal_order=my_seasonal_order,enforce_stationarity=False,enforce_invertibility=False)
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    predict_log.append(output[0])
    yhat = 10**output[0]
    predictions.append(yhat)
    obs = test_log[t]
    history.append(obs)
   # print('predicted=%f, expected=%f' % (output[0], obs))
#error = math.sqrt(mean_squared_error(test_log, predict_log))
#print('Test rmse: %.3f' % error)
# plot
figsize=(12, 7)
plt.figure(figsize=figsize)
pyplot.plot(test,label='Actuals')
pyplot.plot(predictions, color='red',label='Predicted')
pyplot.legend(loc='upper right')
pyplot.show()

# %%
from pmdarima import auto_arima
stepwise_model = auto_arima(train_log, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=7,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[7]             : AIC=181.102, Time=0.61 sec
#  ARIMA(0,1,0)(0,1,0)[7]             : AIC=198.165, Time=0.05 sec
#  ARIMA(1,1,0)(1,1,0)[7]             : AIC=195.263, Time=0.12 sec
#  ARIMA(0,1,1)(0,1,1)[7]             : AIC=186.869, Time=0.05 sec
#  ARIMA(1,1,1)(0,1,0)[7]             : AIC=inf, Time=0.12 sec
#  ARIMA(1,1,1)(1,1,1)[7]             : AIC=180.997, Time=0.14 sec
#  ARIMA(1,1,1)(1,1,0)[7]             : AIC=184.538, Time=0.11 sec
#  ARIMA(1,1,1)(2,1,1)[7]             : AIC=181.877, Time=0.22 sec
#  ARIMA(1,1,1)(1,1,2)[7]             : AIC=182.062, Time=0.26 sec
#  ARIMA(1,1,1)(0,1,2)[7]             : AIC=180.261, Time=0.24 sec
#  ARIMA(0,1,1)(0,1,2)[7]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,1,0)(0,1,2)[7]             : AIC=189.800, Time=0.17 sec
#  ARIMA(2,1,1)(0,1,2)[7]             : AIC=181.880, Time=0.33 sec
#  ARIMA(1,1,2)(0,1,2)[7]             : AIC=181.814, Time=0.48 sec
# ...

# %%
import math
import statsmodels.api as sm
import statsmodels.tsa.api as smt
from sklearn.metrics import mean_squared_error
train, test = actual_vals[0:-70], actual_vals[-70:]
train_log, test_log = np.log10(train), np.log10(test)
# split data into train and test-sets
history = [x for x in train_log]
predictions = list()
predict_log=list()
for t in range(len(test_log)):
    #model = sm.tsa.SARIMAX(history, order=my_order, seasonal_order=my_seasonal_order,enforce_stationarity=False,enforce_invertibility=False)
    stepwise_model.fit(history)
    output = stepwise_model.predict(n_periods=1)
    predict_log.append(output[0])
    yhat = 10**output[0]
    predictions.append(yhat)
    obs = test_log[t]
    history.append(obs)
    #print('predicted=%f, expected=%f' % (output[0], obs))
#error = math.sqrt(mean_squared_error(test_log, predict_log))
#print('Test rmse: %.3f' % error)
# plot
figsize=(12, 7)
plt.figure(figsize=figsize)
pyplot.plot(test,label='Actuals')
pyplot.plot(predictions, color='red',label='Predicted')
pyplot.legend(loc='upper right')
pyplot.show()

# %%
predicted_df=pd.DataFrame()
predicted_df['Fecha']=time_series_df['Fecha'][-70:]
predicted_df['actuals']=test
predicted_df['predicted']=predictions
predicted_df.reset_index(inplace=True)
del predicted_df['index']
predicted_df.head()
# Out:
#                 Fecha  actuals    predicted
# 0 2021-09-19 17:00:00       80  4837.697686
# 1 2021-09-19 23:00:00      124   366.285077
# 2 2021-09-20 00:00:00     8726  2047.160824
# 3 2021-09-20 01:00:00     8769  3349.087557
# 4 2021-09-20 02:00:00     8612  4758.015207

# %%
def detect_classify_anomalies(df,window):
    df.replace([np.inf, -np.inf], np.NaN, inplace=True)
    df.fillna(0,inplace=True)
    df['error']=df['actuals']-df['predicted']
    df['percentage_change'] = ((df['actuals'] - df['predicted']) / df['actuals']) * 100
    df['meanval'] = df['error'].rolling(window=window).mean()
    df['deviation'] = df['error'].rolling(window=window).std()
    df['-3s'] = df['meanval'] - (2 * df['deviation'])
    df['3s'] = df['meanval'] + (2 * df['deviation'])
    df['-2s'] = df['meanval'] - (1.75 * df['deviation'])
    df['2s'] = df['meanval'] + (1.75 * df['deviation'])
    df['-1s'] = df['meanval'] - (1.5 * df['deviation'])
    df['1s'] = df['meanval'] + (1.5 * df['deviation'])
    cut_list = df[['error', '-3s', '-2s', '-1s', 'meanval', '1s', '2s', '3s']]
    cut_values = cut_list.values
    cut_sort = np.sort(cut_values)
    df['impact'] = [(lambda x: np.where(cut_sort == df['error'][x])[1][0])(x) for x in
                               range(len(df['error']))]
    severity = {0: 3, 1: 2, 2: 1, 3: 0, 4: 0, 5: 1, 6: 2, 7: 3}
    region = {0: "NEGATIVE", 1: "NEGATIVE", 2: "NEGATIVE", 3: "NEGATIVE", 4: "POSITIVE", 5: "POSITIVE", 6: "POSITIVE",
              7: "POSITIVE"}
    df['color'] =  df['impact'].map(severity)
    df['region'] = df['impact'].map(region)
    df['anomaly_points'] = np.where(df['color'] == 3, df['error'], np.nan)
    df = df.sort_values(by='Fecha', ascending=False)
    df.load_date = pd.to_datetime(df['Fecha'].astype(str), format="%Y-%m-%d")
    return df

# %%
def plot_anomaly(df,metric_name):
    #error = pd.DataFrame(Order_results.error.values)
    #df = df.sort_values(by='load_date', ascending=False)
    #df.load_date = pd.to_datetime(df['load_date'].astype(str), format="%Y%m%d")
    dates = df.Fecha
    #meanval = error.rolling(window=window).mean()
    #deviation = error.rolling(window=window).std()
    #res = error
#upper_bond=meanval + (2 * deviation)
    #lower_bond=meanval - (2 * deviation)
#anomalies = pd.DataFrame(index=res.index, columns=res.columns)
    #anomalies[res < lower_bond] = res[res < lower_bond]
    #anomalies[res > upper_bond] = res[res > upper_bond]
    bool_array = (abs(df['anomaly_points']) > 0)
#And a subplot of the Actual Values.
    actuals = df["actuals"][-len(bool_array):]
    anomaly_points = bool_array * actuals
    anomaly_points[anomaly_points == 0] = np.nan
#Order_results['meanval']=meanval
    #Order_results['deviation']=deviation
    color_map= {0: "rgba(228, 222, 249, 0.65)", 1: "yellow", 2: "orange", 3: "red"}
    table = go.Table(
    domain=dict(x=[0, 1],
                y=[0, 0.3]),
    columnwidth=[1, 2 ],
    #columnorder=[0, 1, 2,],
    header = dict(height = 20,
                  values = [['<b>Date</b>'],['<b>Actual Values </b>'],
                            ['<b>Predicted</b>'], ['<b>% Difference</b>'],['<b>Severity (0-3)</b>']],
                 font = dict(color=['rgb(45, 45, 45)'] * 5, size=14),
                  fill = dict(color='#d562be')),
    cells = dict(values = [df.round(3)[k].tolist() for k in ['Fecha', 'actuals', 'predicted',
                                                               'percentage_change','color']],
                 line = dict(color='#506784'),
                 align = ['center'] * 5,
                 font = dict(color=['rgb(40, 40, 40)'] * 5, size=12),
                 #format = [None] + [",.4f"] + [',.4f'],
#suffix=[None] * 4,
                 suffix=[None] + [''] + [''] + ['%'] + [''],
                 height = 27,
                 #fill = dict(color=['rgb(235, 193, 238)', 'rgba(228, 222, 249, 0.65)']))
                 fill=dict(color=  # ['rgb(245,245,245)',#unique color for the first column
                                      [df['color'].map(color_map)],
                                      )
                    ))
                #df['ano'] = np.where(df['color']==3, df['error'], np.nan)
    anomalies = go.Scatter(name="Anomaly",
                                       x=dates,
                                       xaxis='x1',
                                       yaxis='y1',
                                       y=df['anomaly_points'],
                                       mode='markers',
                                       marker = dict(color ='red',
                                      size = 11,line = dict(
                                                         color = "red",
                                                         width = 2)))
    upper_bound = go.Scatter(hoverinfo="skip",
                                         x=dates,
                                         showlegend =False,
                                         xaxis='x1',
                                         yaxis='y1',
                                         y=df['3s'],
                                         marker=dict(color="#444"),
                                         line=dict(
                                             color=('rgb(23, 96, 167)'),
                                             width=2,
                                             dash='dash'),
                                         fillcolor='rgba(68, 68, 68, 0.3)',
                                         fill='tonexty')
    lower_bound = go.Scatter(name='Confidence Interval',
                                          x=dates,
                                         xaxis='x1',
                                         yaxis='y1',
                                          y=df['-3s'],
                                          marker=dict(color="#444"),
                                          line=dict(
                                              color=('rgb(23, 96, 167)'),
                                              width=2,
                                              dash='dash'),
                                          fillcolor='rgba(68, 68, 68, 0.3)',
                                          fill='tonexty')
    Actuals = go.Scatter(name= 'Actuals',
                                     x= dates,
                                     y= df['actuals'],
                                    xaxis='x2', yaxis='y2',
                                     mode='lines',
                                     marker=dict(size=12,
                                                 line=dict(width=1),
                                                 color="blue"))
    Predicted = go.Scatter(name= 'Predicted',
                                     x= dates,
                                     y= df['predicted'],
                                    xaxis='x2', yaxis='y2',
                                     mode='lines',
                                     marker=dict(size=12,
                                                 line=dict(width=1),
                                                 color="orange"))
                # create plot for error...
    Error = go.Scatter(name="Error",
                                   x=dates, y=df['error'],
                                   xaxis='x1',
                                   yaxis='y1',
                                   mode='lines',
                                   marker=dict(size=12,
                                               line=dict(width=1),
                                               color="red"),
                                   text="Error")
    anomalies_map = go.Scatter(name = "anomaly actual",
                                                   showlegend=False,
                                                   x=dates,
                                                   y=anomaly_points,
                                                   mode='markers',
                                                   xaxis='x2',
                                                   yaxis='y2',
                                                    marker = dict(color ="red",
                                                  size = 11,
                                                 line = dict(
                                                     color = "red",
                                                     width = 2)))
    Mvingavrg = go.Scatter(name="Moving Average",
                                           x=dates,
                                           y=df['meanval'],
                                           mode='lines',
                                           xaxis='x1',
                                           yaxis='y1',
                                           marker=dict(size=12,
                                                       line=dict(width=1),
                                                       color="green"),
                                           text="Moving average")
    axis=dict(
                    showline=True,
                    zeroline=False,
                    showgrid=True,
                    mirror=True,
                    ticklen=4,
                    gridcolor='#ffffff',
                    tickfont=dict(size=10))
    layout = dict(
                    width=1000,
                    height=865,
                    autosize=False,
                    title= metric_name,
                    margin = dict(t=75),
                    showlegend=True,
                    xaxis1=dict(axis, **dict(domain=[0, 1], anchor='y1', showticklabels=True)),
                    xaxis2=dict(axis, **dict(domain=[0, 1], anchor='y2', showticklabels=True)),
                    yaxis1=dict(axis, **dict(domain=[2 * 0.21 + 0.20 + 0.09, 1], anchor='x1', hoverformat='.2f')),
                    yaxis2=dict(axis, **dict(domain=[0.21 + 0.12, 2 * 0.31 + 0.02], anchor='x2', hoverformat='.2f')))
    fig = go.Figure(data = [table,anomalies,anomalies_map,
                                        upper_bound,lower_bound,Actuals,Predicted,
                                        Mvingavrg,Error], layout = layout)
    
    fig.show()
classify_df=detect_classify_anomalies(predicted_df,7)
classify_df.reset_index(inplace=True)
del classify_df['index']
classify_df.head()
# Out:
# <ipython-input-282-ac34224f8c64>:26: UserWarning:
#
# Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#                 Fecha  actuals     predicted        error  percentage_change  \
# 0 2021-09-22 16:00:00       47    638.747916  -591.747916       -1259.038119
# 1 2021-09-22 13:00:00        4   6470.215981 -6466.215981     -161655.399521
# 2 2021-09-22 12:00:00     4999   6791.712069 -1792.712069         -35.861414
# 3 2021-09-22 11:00:00     9188   6457.407589  2730.592411          29.719116
# 4 2021-09-22 10:00:00     8296  10365.479408 -2069.479408         -24.945509
#
#        meanval    deviation          -3s           3s          -2s  \
# 0  -821.805248  3461.295805 -7744.396858  6100.786362 -6879.072907
# 1   149.604977  4371.211144 -8592.817311  8892.027265 -7500.014525
# 2  1265.820247  3255.475647 -5245.131047  7776.771542 -4431.262135
# ...

# %%
plot_anomaly(classify_df.iloc[:-6,:],"metric_name")
# Out:
# <div>                            <div id="4db3f200-d071-4951-9a45-d5c5207844a9" class="plotly-graph-div" style="height:865px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4db3f200-d071-4951-9a45-d5c5207844a9")) {                    Plotly.newPlot(                        "4db3f200-d071-4951-9a45-d5c5207844a9",                        [{"cells":{"align":["center","center","center","center","center"],"fill":{"color":[["rgba(228, 222, 249, 0.65)","yellow","rgba(228, 222, 249, 0.65)","rgba(228, 222, 249, 0.65)","rgba(228, 222, 249, 0.65)","rgba(228, 222, 249, 0.65)","rgba(228, 222, 249, 0.65)","orange","rgba(228, 222, 249, 0.65)","yellow","rgba(228, 222, 249, 0.65)","rgba(228, 222, 249, 0.65)","rgba(228, 222, 249, 0.65)","rgba(228, 222, 249, 0.65)","rgba(228, 222, 249, 0.65)","rgba(228, 222, 249
# ...
